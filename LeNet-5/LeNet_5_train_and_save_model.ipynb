# %% [markdown]
# <a href="https://colab.research.google.com/github/user1896/Neural-Network-image-classification/blob/main/LeNet-5/LeNet_5_train_and_save_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LeNet-5 MODEL

# %%
from __future__ import print_function
import json
import keras
import pickle
import os.path
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LambdaCallback
from keras import optimizers
from keras import regularizers
from keras.utils.vis_utils import plot_model
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Model
from keras.layers import Input
from keras.layers import add
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load DataSet

# %%
# load train and test dataset
def load_dataset():
  # load dataset
  (trainX, trainY), (testX, testY) = cifar10.load_data()
  # one hot encode target values
  trainY = to_categorical(trainY)
  testY = to_categorical(testY)
  return trainX, trainY, testX, testY

# %% [markdown]
# # Prepare Pixel Data

# %%
#We know that the pixel values for each image in the dataset are unsigned integers in the range
#between black and white, or 0 and 255. We do not know the best way to scale the pixel values
#for modeling, but we know that some scaling will be required. A good starting point is to
#normalize the pixel values of grayscale images, e.g. rescale them to the range [0,1]. This involves
#first converting the data type from unsigned integers to floats, then dividing the pixel values by
#the maximum value.
# scale pixels
def prep_pixels(train, test):
  # convert from integers to floats
  train_norm = train.astype( 'float32' )
  test_norm = test.astype( 'float32' )
  # normalize to range 0-1
  train_norm = train_norm / 255.0
  test_norm = test_norm / 255.0
  # return normalized images
  return train_norm, test_norm

# %% [markdown]
# # Define The Model

# %%
# define cnn model
def define_model():
  model = Sequential()

  model.add(Conv2D(6, (3, 3), activation= 'relu' , kernel_initializer= 'he_uniform' , padding= 'same' , input_shape=(32, 32, 3)))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(16, (3, 3), activation= 'relu' , kernel_initializer= 'he_uniform' , padding= 'same' ))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.3))

  model.add(Flatten())

  model.add(Dense(120, activation= 'relu' , kernel_initializer= 'he_uniform' ))
  model.add(BatchNormalization())
  model.add(Dropout(0.4))

  model.add(Dense(84, activation= 'relu' , kernel_initializer= 'he_uniform' ))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Dense(10, activation= 'softmax' ))

  # compile model
  # opt = SGD(lr=0.001, momentum=0.9)
  model.compile(optimizer='adam', loss= 'categorical_crossentropy' , metrics=[ 'accuracy' ])
  return model

# %%
# load dataset
trainX, trainY, testX, testY = load_dataset()
# prepare pixel data
trainX, testX = prep_pixels(trainX, testX)
# define model
model = define_model()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
# summarize model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 6)         168
#
#  batch_normalization (BatchN  (None, 32, 32, 6)        24
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 6)        0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 6)         0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        880
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 16)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 120)               123000
#
#  batch_normalization_2 (Batc  (None, 120)              480
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  batch_normalization_3 (Batc  (None, 84)               336
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 84)                0
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 135,966
# Trainable params: 135,514
# Non-trainable params: 452
# _________________________________________________________________

# %% [markdown]
# # Model Architecture

# %%
# plot model architecture
plot_model(model, show_shapes=True, to_file= 'lenet_block.png' )

# %% [markdown]
# # Data Augmentation

# %%
# create data generator
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1,
horizontal_flip=True)
# prepare iterator
it_train = datagen.flow(trainX, trainY, batch_size=64)

# %% [markdown]
# # Train The Model

# %%
# fit model
steps = int(trainX.shape[0] / 64)
history = model.fit_generator(it_train, steps_per_epoch=steps, epochs=70, validation_data=(testX,
testY), verbose=1)
# Out:
# Epoch 1/70
# <ipython-input-9-c29c10b94f9a>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(it_train, steps_per_epoch=steps, epochs=70, validation_data=(testX,
# 781/781 [==============================] - 102s 128ms/step - loss: 2.0633 - accuracy: 0.2880 - val_loss: 1.5668 - val_accuracy: 0.4303
# Epoch 2/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.6861 - accuracy: 0.3899 - val_loss: 1.4519 - val_accuracy: 0.4727
# Epoch 3/70
# 781/781 [==============================] - 97s 125ms/step - loss: 1.5976 - accuracy: 0.4231 - val_loss: 1.5396 - val_accuracy: 0.4393
# Epoch 4/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.5302 - accuracy: 0.4499 - val_loss: 1.3490 - val_accuracy: 0.5032
# Epoch 5/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.4886 - accuracy: 0.4640 - val_loss: 1.2894 - val_accuracy: 0.5296
# Epoch 6/70
# 781/781 [==============================] - 100s 128ms/step - loss: 1.4487 - accuracy: 0.4791 - val_loss: 1.3084 - val_accuracy: 0.5184
# Epoch 7/70
# 781/781 [==============================] - 109s 139ms/step - loss: 1.4259 - accuracy: 0.4901 - val_loss: 1.3200 - val_accuracy: 0.5148
# Epoch 8/70
# 781/781 [==============================] - 99s 127ms/step - loss: 1.3989 - accuracy: 0.5035 - val_loss: 1.2699 - val_accuracy: 0.5490
# Epoch 9/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.3834 - accuracy: 0.5087 - val_loss: 1.4453 - val_accuracy: 0.4906
# Epoch 10/70
# 781/781 [==============================] - 98s 126ms/step - loss: 1.3639 - accuracy: 0.5154 - val_loss: 1.2792 - val_accuracy: 0.5424
# Epoch 11/70
# 781/781 [==============================] - 93s 118ms/step - loss: 1.3388 - accuracy: 0.5262 - val_loss: 1.1203 - val_accuracy: 0.5976
# Epoch 12/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.3271 - accuracy: 0.5352 - val_loss: 1.3817 - val_accuracy: 0.5176
# Epoch 13/70
# 781/781 [==============================] - 100s 128ms/step - loss: 1.3157 - accuracy: 0.5365 - val_loss: 1.1191 - val_accuracy: 0.6004
# Epoch 14/70
# 781/781 [==============================] - 93s 119ms/step - loss: 1.3041 - accuracy: 0.5430 - val_loss: 1.2430 - val_accuracy: 0.5607
# Epoch 15/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.2940 - accuracy: 0.5434 - val_loss: 1.0621 - val_accuracy: 0.6221
# Epoch 16/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.2817 - accuracy: 0.5484 - val_loss: 1.0061 - val_accuracy: 0.6420
# Epoch 17/70
# 781/781 [==============================] - 98s 126ms/step - loss: 1.2737 - accuracy: 0.5526 - val_loss: 1.1054 - val_accuracy: 0.6050
# Epoch 18/70
# 781/781 [==============================] - 92s 118ms/step - loss: 1.2728 - accuracy: 0.5534 - val_loss: 1.0686 - val_accuracy: 0.6176
# Epoch 19/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2609 - accuracy: 0.5600 - val_loss: 1.0734 - val_accuracy: 0.6151
# Epoch 20/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2558 - accuracy: 0.5626 - val_loss: 1.0338 - val_accuracy: 0.6290
# Epoch 21/70
# 781/781 [==============================] - 100s 128ms/step - loss: 1.2500 - accuracy: 0.5653 - val_loss: 1.1588 - val_accuracy: 0.5870
# Epoch 22/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2387 - accuracy: 0.5647 - val_loss: 1.1380 - val_accuracy: 0.5975
# Epoch 23/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2416 - accuracy: 0.5657 - val_loss: 1.1904 - val_accuracy: 0.5801
# Epoch 24/70
# 781/781 [==============================] - 96s 122ms/step - loss: 1.2381 - accuracy: 0.5661 - val_loss: 1.0239 - val_accuracy: 0.6402
# Epoch 25/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.2190 - accuracy: 0.5743 - val_loss: 1.0424 - val_accuracy: 0.6303
# Epoch 26/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.2237 - accuracy: 0.5718 - val_loss: 0.9732 - val_accuracy: 0.6557
# Epoch 27/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.2130 - accuracy: 0.5760 - val_loss: 1.0036 - val_accuracy: 0.6418
# Epoch 28/70
# 781/781 [==============================] - 96s 124ms/step - loss: 1.2222 - accuracy: 0.5744 - val_loss: 0.9918 - val_accuracy: 0.6492
# Epoch 29/70
# 781/781 [==============================] - 99s 127ms/step - loss: 1.2098 - accuracy: 0.5807 - val_loss: 1.1655 - val_accuracy: 0.5929
# Epoch 30/70
# 781/781 [==============================] - 93s 120ms/step - loss: 1.2085 - accuracy: 0.5792 - val_loss: 1.1795 - val_accuracy: 0.5824
# Epoch 31/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.2106 - accuracy: 0.5792 - val_loss: 0.9530 - val_accuracy: 0.6621
# Epoch 32/70
# 781/781 [==============================] - 98s 125ms/step - loss: 1.2059 - accuracy: 0.5792 - val_loss: 1.0377 - val_accuracy: 0.6321
# Epoch 33/70
# 781/781 [==============================] - 99s 126ms/step - loss: 1.2028 - accuracy: 0.5831 - val_loss: 1.0038 - val_accuracy: 0.6442
# Epoch 34/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.1965 - accuracy: 0.5838 - val_loss: 1.0023 - val_accuracy: 0.6464
# Epoch 35/70
# 781/781 [==============================] - 95s 121ms/step - loss: 1.1932 - accuracy: 0.5859 - val_loss: 0.9192 - val_accuracy: 0.6740
# Epoch 36/70
# 781/781 [==============================] - 98s 125ms/step - loss: 1.1921 - accuracy: 0.5849 - val_loss: 0.9644 - val_accuracy: 0.6563
# Epoch 37/70
# 781/781 [==============================] - 102s 130ms/step - loss: 1.1816 - accuracy: 0.5868 - val_loss: 0.9970 - val_accuracy: 0.6496
# Epoch 38/70
# 781/781 [==============================] - 93s 119ms/step - loss: 1.1865 - accuracy: 0.5867 - val_loss: 0.9946 - val_accuracy: 0.6445
# Epoch 39/70
# 781/781 [==============================] - 98s 125ms/step - loss: 1.1804 - accuracy: 0.5894 - val_loss: 1.0590 - val_accuracy: 0.6271
# Epoch 40/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.1793 - accuracy: 0.5899 - val_loss: 0.9413 - val_accuracy: 0.6670
# Epoch 41/70
# 781/781 [==============================] - 93s 119ms/step - loss: 1.1802 - accuracy: 0.5898 - val_loss: 1.0596 - val_accuracy: 0.6241
# Epoch 42/70
# 781/781 [==============================] - 93s 120ms/step - loss: 1.1767 - accuracy: 0.5895 - val_loss: 0.9669 - val_accuracy: 0.6588
# Epoch 43/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.1728 - accuracy: 0.5914 - val_loss: 0.9928 - val_accuracy: 0.6449
# Epoch 44/70
# 781/781 [==============================] - 96s 122ms/step - loss: 1.1720 - accuracy: 0.5910 - val_loss: 0.9876 - val_accuracy: 0.6469
# Epoch 45/70
# 781/781 [==============================] - 98s 126ms/step - loss: 1.1746 - accuracy: 0.5911 - val_loss: 0.9314 - val_accuracy: 0.6742
# Epoch 46/70
# 781/781 [==============================] - 93s 119ms/step - loss: 1.1714 - accuracy: 0.5920 - val_loss: 0.9277 - val_accuracy: 0.6768
# Epoch 47/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.1634 - accuracy: 0.5968 - val_loss: 1.1467 - val_accuracy: 0.5906
# Epoch 48/70
# 781/781 [==============================] - 96s 122ms/step - loss: 1.1686 - accuracy: 0.5934 - val_loss: 0.9334 - val_accuracy: 0.6690
# Epoch 49/70
# 781/781 [==============================] - 94s 121ms/step - loss: 1.1671 - accuracy: 0.5947 - val_loss: 1.0052 - val_accuracy: 0.6456
# Epoch 50/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.1610 - accuracy: 0.5975 - val_loss: 0.9799 - val_accuracy: 0.6489
# Epoch 51/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.1628 - accuracy: 0.5985 - val_loss: 0.8803 - val_accuracy: 0.6920
# Epoch 52/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.1536 - accuracy: 0.6016 - val_loss: 0.8888 - val_accuracy: 0.6889
# Epoch 53/70
# 781/781 [==============================] - 100s 127ms/step - loss: 1.1631 - accuracy: 0.5964 - val_loss: 1.0038 - val_accuracy: 0.6438
# Epoch 54/70
# 781/781 [==============================] - 98s 126ms/step - loss: 1.1570 - accuracy: 0.5980 - val_loss: 0.9104 - val_accuracy: 0.6843
# Epoch 55/70
# 781/781 [==============================] - 94s 120ms/step - loss: 1.1540 - accuracy: 0.5993 - val_loss: 0.9806 - val_accuracy: 0.6528
# Epoch 56/70
# 781/781 [==============================] - 95s 121ms/step - loss: 1.1536 - accuracy: 0.6006 - val_loss: 0.8736 - val_accuracy: 0.6970
# Epoch 57/70
# 781/781 [==============================] - 96s 122ms/step - loss: 1.1547 - accuracy: 0.5991 - val_loss: 0.9058 - val_accuracy: 0.6803
# Epoch 58/70
# 781/781 [==============================] - 100s 128ms/step - loss: 1.1500 - accuracy: 0.6012 - val_loss: 1.0985 - val_accuracy: 0.6117
# Epoch 59/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.1459 - accuracy: 0.6048 - val_loss: 0.8925 - val_accuracy: 0.6889
# Epoch 60/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.1506 - accuracy: 0.5993 - val_loss: 0.9388 - val_accuracy: 0.6697
# Epoch 61/70
# 781/781 [==============================] - 98s 125ms/step - loss: 1.1516 - accuracy: 0.6000 - val_loss: 0.9366 - val_accuracy: 0.6676
# Epoch 62/70
# 781/781 [==============================] - 98s 126ms/step - loss: 1.1485 - accuracy: 0.6024 - val_loss: 0.9238 - val_accuracy: 0.6689
# Epoch 63/70
# 781/781 [==============================] - 95s 121ms/step - loss: 1.1468 - accuracy: 0.6002 - val_loss: 0.9561 - val_accuracy: 0.6582
# Epoch 64/70
# 781/781 [==============================] - 96s 123ms/step - loss: 1.1465 - accuracy: 0.6029 - val_loss: 0.9623 - val_accuracy: 0.6585
# Epoch 65/70
# 781/781 [==============================] - 99s 126ms/step - loss: 1.1425 - accuracy: 0.6029 - val_loss: 0.8669 - val_accuracy: 0.6998
# Epoch 66/70
# 781/781 [==============================] - 95s 121ms/step - loss: 1.1426 - accuracy: 0.6026 - val_loss: 0.9221 - val_accuracy: 0.6749
# Epoch 67/70
# 781/781 [==============================] - 95s 122ms/step - loss: 1.1381 - accuracy: 0.6057 - val_loss: 0.9714 - val_accuracy: 0.6538
# Epoch 68/70
# 781/781 [==============================] - 99s 127ms/step - loss: 1.1386 - accuracy: 0.6067 - val_loss: 0.9462 - val_accuracy: 0.6658
# Epoch 69/70
# 781/781 [==============================] - 96s 122ms/step - loss: 1.1372 - accuracy: 0.6061 - val_loss: 0.9704 - val_accuracy: 0.6566
# Epoch 70/70
# 781/781 [==============================] - 97s 124ms/step - loss: 1.1400 - accuracy: 0.6058 - val_loss: 0.9314 - val_accuracy: 0.6712

# %% [markdown]
# # Evaluate The Model

# %%
# Plot loss per iteration
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# evaluate model
_ , acc = model.evaluate(testX, testY, verbose=0)
print( ' > %.3f ' % (acc * 100.0))
# Out:
#  > 67.120

# %% [markdown]
# # Save The Model

# %%
# Save our model to a file
# Must save as a .h5 format to be able to download it to your pc
model.save('LeNetGC.h5')

# %%
# Check that the model file exists
# !ls -1h
